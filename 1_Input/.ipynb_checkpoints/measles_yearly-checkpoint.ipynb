# %%
import pandas as pd
import numpy as np
from functools import reduce


diseases = ["measles", "mumps", "rubella", "hepatitis", "pertussis", "rubella", "smallpox", "polio"]
DFList = []

for item in diseases:
    print(item)
# Out:
# measles
# mumps
# rubella
# hepatitis
# pertussis
# rubella
# smallpox
# polio

# %%
for item in diseases:
    
    #READ CSV TO DATAFRAME
    #establish csv read path
    inputPath = "dataSource/contagious-diseases/" + item + ".csv"
    #read csv
    data = pd.read_csv(inputPath) 
    #show data head
    data.head()
    #confirm data read
    print("read: " + inputPath)
    
    
    #GET YEAR FOR EACH ENTRY AND GROUPBY FOR SUM OF CASES
    #extract year from year-week date and add to new column
    data["year"] = data['week'].astype(str).str[:-2].astype(np.int64)
    #print new table with year column
    data.head()
    #group by with sum cases per year and state_name
    data_append = pd.DataFrame(data.groupby(["state_name", "year"])["cases"].sum())
    #show data head after groupby
    data_append.head()
    
    
    #APPEND ALL DFs TO A LIST
    #establish DF name
    DFName = item + "DF"
    #select columns from data
    data_forDFList = data [["state", "year", "cases"]]
    #convert to concise dataframe with new column names
    data_forDFList = data_forDFList.rename(columns={'state': 'state', 'year': "year", "cases": item + "_cases"})
    #convert data to DF
    data_forDFList.name = DFName
    #comfirm data converted to DFName
    print(data_forDFList.name + " = data")
    #append data with name to DFList
    DFList.append(data_forDFList)
    
    
    #WRITE CSV TO DATAFRAME
    #establish csv write path
    outputPath = "inputData/" + item + "_byYear.csv"
    #write csv
    data_append.to_csv(outputPath)
    #confirm data write
    print("written: " + outputPath + "\n")   
    
for i in DFList:
    print(i.head())
# Out:
# read: dataSource/contagious-diseases/measles.csv
# measlesDF = data
# written: inputData/measles_byYear.csv
#
# read: dataSource/contagious-diseases/mumps.csv
# mumpsDF = data
# written: inputData/mumps_byYear.csv
#
# read: dataSource/contagious-diseases/rubella.csv
# rubellaDF = data
# written: inputData/rubella_byYear.csv
#
# read: dataSource/contagious-diseases/hepatitis.csv
# hepatitisDF = data
# written: inputData/hepatitis_byYear.csv
#
# read: dataSource/contagious-diseases/pertussis.csv
# pertussisDF = data
# written: inputData/pertussis_byYear.csv
#
# read: dataSource/contagious-diseases/rubella.csv
# rubellaDF = data
# written: inputData/rubella_byYear.csv
#
# read: dataSource/contagious-diseases/smallpox.csv
# smallpoxDF = data
# written: inputData/smallpox_byYear.csv
#
# read: dataSource/contagious-diseases/polio.csv
# polioDF = data
# written: inputData/polio_byYear.csv
#
#   state  year  measles_cases
# 0    AL  1928             97
# 1    AR  1928             76
# 2    AZ  1928              8
# 3    CA  1928             74
# 4    CO  1928             85
#   state  year  mumps_cases
# 0    AK  1968            7
# 1    AL  1968           39
# 2    AZ  1968           19
# 3    CA  1968          247
# 4    DC  1968            1
#   state  year  rubella_cases
# 0    AL  1966              7
# 1    AZ  1966             29
# 2    CA  1966              7
# 3    CT  1966             11
# 4    HI  1966              1
#   state  year  hepatitis_cases
# 0    AL  1966                5
# 1    AR  1966               11
# 2    AZ  1966                6
# 3    CA  1966               89
# 4    CO  1966                1
#   state  year  pertussis_cases
# 0    AL  1938               22
# 1    AR  1938               22
# 2    AZ  1938               19
# 3    CA  1938              390
# 4    CO  1938               10
#   state  year  rubella_cases
# 0    AL  1966              7
# 1    AZ  1966             29
# 2    CA  1966              7
# 3    CT  1966             11
# 4    HI  1966              1
#   state  year  smallpox_cases
# 0    AL  1928               1
# 1    AR  1928               7
# 2    AZ  1928               0
# 3    CA  1928              18
# 4    CO  1928              31
#   state  year polio_cases
# 0    AL  1928           0
# 1    AR  1928           0
# 2    AZ  1928           0
# 3    CA  1928           9
# 4    CO  1928           4

# %%
for i in DFList:
    print(i.name)
    print(i.head())
    print("\n")
# Out:
# measlesDF
#   state  year  measles_cases
# 0    AL  1928             97
# 1    AR  1928             76
# 2    AZ  1928              8
# 3    CA  1928             74
# 4    CO  1928             85
#
#
# mumpsDF
#   state  year  mumps_cases
# 0    AK  1968            7
# 1    AL  1968           39
# 2    AZ  1968           19
# 3    CA  1968          247
# 4    DC  1968            1
#
#
# rubellaDF
#   state  year  rubella_cases
# 0    AL  1966              7
# 1    AZ  1966             29
# 2    CA  1966              7
# 3    CT  1966             11
# 4    HI  1966              1
#
#
# hepatitisDF
#   state  year  hepatitis_cases
# 0    AL  1966                5
# 1    AR  1966               11
# 2    AZ  1966                6
# 3    CA  1966               89
# 4    CO  1966                1
#
#
# pertussisDF
#   state  year  pertussis_cases
# 0    AL  1938               22
# 1    AR  1938               22
# 2    AZ  1938               19
# 3    CA  1938              390
# 4    CO  1938               10
#
#
# rubellaDF
#   state  year  rubella_cases
# 0    AL  1966              7
# 1    AZ  1966             29
# 2    CA  1966              7
# 3    CT  1966             11
# 4    HI  1966              1
#
#
# smallpoxDF
#   state  year  smallpox_cases
# 0    AL  1928               1
# 1    AR  1928               7
# 2    AZ  1928               0
# 3    CA  1928              18
# 4    CO  1928              31
#
#
# polioDF
#   state  year polio_cases
# 0    AL  1928           0
# 1    AR  1928           0
# 2    AZ  1928           0
# 3    CA  1928           9
# 4    CO  1928           4

# %%
masterList = DFList[0]


for x in range(1, len(DFList)):
        masterList.merge(DFList[x], left_on=["state","year"], right_on=["state","year"])


#for i in DFList:
    #print(i)
#    masterList = pd.merge(masterList, i, how="left", on=["state","year"])

masterList

#df_final = reduce(lambda left,right: pd.merge(how = "left", on=["state","year"],), DFList)
#df_final
#merge_table = pd.merge(DFList[0], DFList[1],  on=["state","year"], how="left")
#merge_table
#print(DFList[0].head())
#print(DFList[1].head())
#DFList[0].merge(DFList[1], left_on=["state","year"], right_on=["state","year"])
